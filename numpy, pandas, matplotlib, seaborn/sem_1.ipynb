# %% [markdown]
# # Семинар 1
#
# **Тема:** Использование библиотек numpy, pandas, matplotlib, seaborn.
#
# ### Задания для самостоятельного выполнения
#
# ***numpy***
# 1. С помощью массивов numpy создайте таблицу умножения.
# 2. Создайте функцию, которая принимает как аргументы целое число N и первый элемент (вещественное число), и разность (вещественное число) и создает матрицу numpy по диагонали, которой располагаются первые N членов арифметической прогрессии.
# 3. Сгенерируйте средствами numpy матрицу А 5 на 5, содержащую последовательные числа от 1 до 25. Используя срезы извлеките в плоский массив все нечетные элементы этой матрицы.
# 4.(ДЗ) Создайте двумерный массив, содержащий единицы на границе и нули внутри.
# 5. Создайте две матрицы размером 5 $\times$ 5. Первая матрица должна содержать цифру 5 в шахматном порядке, остальные значения - нули. Вторая матрица - треугольная, состоящая из цифры 5 на местах с ненулевыми значениями. Посчитайте их детерминанты и найдите обратные матрицы (если это возможно).
#
# ***pandas***
#
# 6. С помощью pandas загрузите датасет для предсказания цены квартиры, прилагающийся к этой работе.
# 7. Выведите на экран несколько первых и несколько последний строк файла.
# 8. Выведите с помощью методов pandas основные количественные характеристики датасета: количество строк, количество столбцов, тип данных каждого поля, статистика каждого числового поля, статистика для полей типа "объект".
# 9. Удалите из таблицы столбцы, содержащие идентификаторы. Переименуйте все оставшиеся названия колонок на русский язык.
# 10. Выведите отдельно столбец, содержащий цену, по его номеру столбца и по названию. Выведите первую, десятую и предпоследнюю строку таблицы.
# 11. Выделите в отдельную таблицу последние десять строк. Уберите в ней столбец с ценой. Склейте ее с первоначальной таблицей при помощи concat. Заполните отсутствующие значения цены средним по таблице.
# 12.(ДЗ) Выделите пять последних колонок в отдельную таблицу. Удалите в ней строки, в которых цена ниже среднего. Присоедините эту таблицу к изначальной (выберите самый подходящий тип соединения).
# 13. Выведите таблицу из первоначального набора данных, содержащую площадь квартиры и цену только для трёхкомнатных квартир.
# 14. Сохраните получившуюся таблицу в файлы формата csv и xlsx. Прочитайте их и убедитесь, что данные отображаются корректно.
# 15.(ДЗ) Создайте в Excel или другом табличном редакторе таблицу, содержащую несколько численных и текстовых полей. Прочитайте ее в программу при помощи pandas.
#
# ***matplotlib, seaborn***
#
# 16. Используя изначальную версию датасета считайте в ноутбук первые 400 строк.
# 17. Постройте круговую диаграмму для признака Rooms, иллюстрирующую количество квартир в процентах в зависимости от количества комнат. Сделайте сектор с наибольшим числом квартир выдвинутым.
# 18.(ДЗ) Постройте гистограмму по целевой переменной Price. Оцените визуально, по какой цене продаётся наибольшее количество квартир.
# 19. Постройте диаграммы рассеяния для признаков Rooms, Square, HouseFloor, HouseYear в зависимости от целевой переменной Price в одной области figure. Оцените визуально, есть ли среди них такие, на которых разброс точек близок к линейной функции.
# 20.(ДЗ) Постройте ядерную оценку плотности целевой переменной Price. Оцените визуально, напоминает ли полученный график нормальное распределение. Постройте двумерную ядерную оценку плотности для целевой переменной Price и признака HouseFloor, затем оцените визуально на каких этажах и по какой цене продаётся основная масса квартир.
# 21. Постройте ящиковую диаграмму признака Square. Оцените визуально имеются ли выбросы, и, если да, то начиная с какого размера площади значение признака можно считать выбросом.
# 22. При помощи сетки графиков PairGrid визуализируйте попарные отношения признаков Rooms, Square, HouseFloor, HouseYear, Price следующим образом: на диагонали - гистограммы, под диагональю - ядерные оценки плотности, над диагональю - диаграммы рассеяния. По результатам визуализации сделайте выводы.
# 23. Постройте тепловую карту матрицы корреляции (df.corr()) признаков Rooms, Square, HouseFloor, HouseYear, Price. По ней определите, какие признаки являются зависимыми (у таких признаков коэффициент корреляции близок к единице).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. С помощью массивов numpy создайте таблицу умножения.

# %% [markdown]
# ## 2. Создайте функцию, которая принимает как аргументы целое число N и первый элемент (вещественное число), и разность (вещественное число) и создает матрицу numpy по диагонали, которой располагаются первые N членов арифметической прогрессии.

# %% [markdown]
# ## 3. Сгенерируйте средствами numpy матрицу А 5 на 5, содержащую последовательные числа от 1 до 25. Используя срезы извлеките в плоский массив все нечетные элементы этой матрицы.

# %% [markdown]
# ## 4. Создайте двумерный массив, содержащий единицы на границе и нули внутри.

# %% [markdown]
# ## 5. Создайте две матрицы размером 5 $\times$ 5. Первая матрица должна содержать цифру 5 в шахматном порядке, остальные значения - нули. Вторая матрица - треугольная, состоящая из цифры 5 на местах с ненулевыми значениями. Посчитайте их детерминанты и найдите обратные матрицы (если это возможно).

# %% [markdown]
# ## 6. С помощью pandas загрузите датасет для предсказания цены квартиры, прилагающийся к этой работе.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(10)
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  11809          27    3.0  115.027311         NaN           10.0      4
# 1   3013          22    1.0   39.832524   23.169223            8.0      7
# 2   8215           1    3.0   78.342215   47.671972           10.0      2
# 3   2352           1    1.0   40.409907         NaN            1.0     10
# 4  13866          94    2.0   64.285067   38.562517            9.0     16
# 5   5804          99    3.0   62.528465   47.103833            6.0      9
# 6   8864          44    1.0   33.938750   21.772930            9.0      1
# 7  13072          59    2.0   50.391814   32.893256            8.0      8
# 8   9951           1    1.0   46.887892   44.628132            1.0     12
# 9   8094           6    3.0   79.867477   75.085125            1.0      3
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        10.0       2014   0.075424         B         B        11      3097
# 1         8.0       1966   0.118537         B         B        30      6207
# 2        17.0       1988   0.025609         B         B        33      5261
# 3        22.0       1977   0.007122         B         B         1       264
# 4        16.0       1972   0.282798         B         B        33      8667
# 5         9.0       1972   0.012339         B         B        35      5776
# 6        12.0       1968   0.232205         B         B        24      4860
# 7        17.0       1986   0.019509         B         B        37      7687
# 8        20.0       1977   0.007122         B         B         1       264
# 9        17.0       2014   0.243205         B         B         5      1564
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         0           NaN            0        0       B  305018.871089
# 1         1        1183.0            1        0       B  177734.553407
# 2         0         240.0            3        1       B  282078.720850
# 3         0           NaN            0        1       B  168106.007630
# 4         2           NaN            0        6       B  343995.102962
# 5         1        2078.0            2        4       B  161044.944138
# 6         1          80.0            0        3       B  142402.739272
# 7        11         176.0            5        5       B  326174.175191
# 8         0           NaN            0        1       B  160400.401732
# 9         0         540.0            0        0       B  194756.023945

# %% [markdown]
# ## 7. Выведите на экран несколько первых и несколько последний строк файла.

# %% [markdown]
# ## 8. Выведите с помощью методов pandas основные количественные характеристики датасета: количество строк, количество столбцов, тип данных каждого поля, статистика каждого числового поля, статистика для полей типа "объект".

# %%
df.shape[0]
# Out:
# 10000

# %%
df.shape[1]
# Out:
# 20

# %%
df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %%
df.describe(include = 'object')
# Out:
#        Ecology_2 Ecology_3 Shops_2
# count      10000     10000   10000
# unique         2         2       2
# top            B         B       B
# freq        9903      9725    9175

# %%
df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %% [markdown]
# ## 9. Удалите из таблицы столбцы, содержащие идентификаторы. Переименуйте все оставшиеся названия колонок на русский язык.

# %%
#df = df.drop(['Id','DistrictId'], axis = 1)

# %%
df columns
# Out:
#   Input In [10]
#     df columns
#        ^
# SyntaxError: invalid syntax

# %%
dict_rus = {'Rooms':'Комнаты', 'Square':'Площадь', 'LifeSquare':'Жилая площадь', 'KitchenSquare':'Площадь кухни', 'Floor':'Этаж', 'HouseFloor':'Этажей в доме', 'HouseYear':'Год постройки', 'Ecology_1':'Экология_1', 'Ecology_2':'Экология_2', 'Ecology_3':'Экология_3', 'Social_1':'Социал_1', 'Social_2':'Социал_2', 'Social_3':'Социал_3', 'Healthcare_1':'Здравоохранение_1', 'Helthcare_2':'Здравоохранение_2', 'Shops_1':'Магазины_1', 'Shops_2':'Магазины_2', 'Price':'Цена'}

# %%
df = df.rename(columns = dict_rus)
df.head()
# Out:
#       Id  DistrictId  Комнаты     Площадь  Жилая площадь  Площадь кухни  Этаж  \
# 0  11809          27      3.0  115.027311            NaN           10.0     4
# 1   3013          22      1.0   39.832524      23.169223            8.0     7
# 2   8215           1      3.0   78.342215      47.671972           10.0     2
# 3   2352           1      1.0   40.409907            NaN            1.0    10
# 4  13866          94      2.0   64.285067      38.562517            9.0    16
#
#    Этажей в доме  Год постройки  Экология_1 Экология_2 Экология_3  Социал_1  \
# 0           10.0           2014    0.075424          B          B        11
# 1            8.0           1966    0.118537          B          B        30
# 2           17.0           1988    0.025609          B          B        33
# 3           22.0           1977    0.007122          B          B         1
# 4           16.0           1972    0.282798          B          B        33
#
#    Социал_2  Социал_3  Здравоохранение_1  Здравоохранение_2  Магазины_1  \
# 0      3097         0                NaN                  0           0
# 1      6207         1             1183.0                  1           0
# 2      5261         0              240.0                  3           1
# 3       264         0                NaN                  0           1
# 4      8667         2                NaN                  0           6
#
#   Магазины_2           Цена
# 0          B  305018.871089
# 1          B  177734.553407
# 2          B  282078.720850
# 3          B  168106.007630
# 4          B  343995.102962

# %% [markdown]
# ## 10. Выведите отдельно столбец, содержащий цену, по его номеру столбца и по названию. Выведите первую, десятую и предпоследнюю строку таблицы.

# %%
df.iloc[:,[17]]
# Out:
#       Магазины_1
# 0              0
# 1              0
# 2              1
# 3              1
# 4              6
# ...          ...
# 9995           9
# 9996           0
# 9997           5
# 9998           5
# 9999           9
#
# [10000 rows x 1 columns]

# %%
df[['Цена']]
# Out:
#                Цена
# 0     305018.871089
# 1     177734.553407
# 2     282078.720850
# 3     168106.007630
# 4     343995.102962
# ...             ...
# 9995  119367.455796
# 9996  199715.148807
# 9997  165953.912580
# 9998  171842.411855
# 9999  177685.627486
#
# [10000 rows x 1 columns]

# %%
df.iloc[[0,9,-2]]
# Out:
#          Id  DistrictId  Комнаты     Площадь  Жилая площадь  Площадь кухни  \
# 0     11809          27      3.0  115.027311            NaN           10.0
# 9      8094           6      3.0   79.867477      75.085125            1.0
# 9998  14561          21      1.0   32.330292      22.326870            5.0
#
#       Этаж  Этажей в доме  Год постройки  Экология_1 Экология_2 Экология_3  \
# 0        4           10.0           2014    0.075424          B          B
# 9        3           17.0           2014    0.243205          B          B
# 9998     3            9.0           1969    0.194489          B          B
#
#       Социал_1  Социал_2  Социал_3  Здравоохранение_1  Здравоохранение_2  \
# 0           11      3097         0                NaN                  0
# 9            5      1564         0              540.0                  0
# 9998        47      8004         3              125.0                  3
#
#       Магазины_1 Магазины_2           Цена
# 0              0          B  305018.871089
# 9              0          B  194756.023945
# 9998           5          B  171842.411855

# %% [markdown]
# ## 11. Выделите в отдельную таблицу последние десять строк. Уберите в ней столбец с ценой. Склейте ее с первоначальной таблицей при помощи concat. Заполните отсутствующие значения цены средним по таблице.

# %%
df1 = df.tail(10)
df1
# Out:
#          Id  DistrictId  Комнаты    Площадь  Жилая площадь  Площадь кухни  \
# 9990  10635          21      1.0  18.983962      11.419796            2.0
# 9991  11173           6      2.0  62.648779            NaN            0.0
# 9992  11753          37      2.0  50.902724      27.159548            6.0
# 9993   9289           1      3.0  84.486078      88.931509            0.0
# 9994   4356           9      1.0  43.303458      21.519087            8.0
# 9995   1260          61      2.0  49.090728      33.272626            6.0
# 9996  16265          27      2.0  64.307684      37.038420            9.0
# 9997   2795         178      1.0  29.648057      16.555363            5.0
# 9998  14561          21      1.0  32.330292      22.326870            5.0
# 9999   7202          94      1.0  35.815476      22.301367            6.0
#
#       Этаж  Этажей в доме  Год постройки  Экология_1 Экология_2 Экология_3  \
# 9990     1            5.0           1967    0.194489          B          B
# 9991     6           17.0           1977    0.243205          B          B
# 9992     4            9.0           1972    0.127812          B          B
# 9993     4           22.0           2016    0.007122          B          B
# 9994    12           14.0           1992    0.161532          B          B
# 9995     3           12.0           1981    0.300323          B          B
# 9996    13            0.0           1977    0.072158          B          B
# 9997     3            5.0           1958    0.460556          B          B
# 9998     3            9.0           1969    0.194489          B          B
# 9999     9            9.0           1975    0.127376          B          B
#
#       Социал_1  Социал_2  Социал_3  Здравоохранение_1  Здравоохранение_2  \
# 9990        47      8004         3              125.0                  3
# 9991         5      1564         0              540.0                  0
# 9992        28      7287         5              320.0                  1
# 9993         1       264         0                NaN                  0
# 9994        25      5648         1               30.0                  2
# 9995        52     10311         6                NaN                  1
# 9996         2       629         1                NaN                  0
# 9997        20      4386        14                NaN                  1
# 9998        47      8004         3              125.0                  3
# 9999        43      8429         3                NaN                  3
#
#       Магазины_1 Магазины_2           Цена
# 9990           5          B  112411.221700
# 9991           0          B  182625.548872
# 9992           3          B  196641.468817
# 9993           1          B  264213.558631
# 9994           4          B  136744.340827
# 9995           9          B  119367.455796
# 9996           0          A  199715.148807
# 9997           5          B  165953.912580
# 9998           5          B  171842.411855
# 9999           9          B  177685.627486

# %%
df1.drop(['Цена'], axis = 1)
# Out:
#          Id  DistrictId  Комнаты    Площадь  Жилая площадь  Площадь кухни  \
# 9990  10635          21      1.0  18.983962      11.419796            2.0
# 9991  11173           6      2.0  62.648779            NaN            0.0
# 9992  11753          37      2.0  50.902724      27.159548            6.0
# 9993   9289           1      3.0  84.486078      88.931509            0.0
# 9994   4356           9      1.0  43.303458      21.519087            8.0
# 9995   1260          61      2.0  49.090728      33.272626            6.0
# 9996  16265          27      2.0  64.307684      37.038420            9.0
# 9997   2795         178      1.0  29.648057      16.555363            5.0
# 9998  14561          21      1.0  32.330292      22.326870            5.0
# 9999   7202          94      1.0  35.815476      22.301367            6.0
#
#       Этаж  Этажей в доме  Год постройки  Экология_1 Экология_2 Экология_3  \
# 9990     1            5.0           1967    0.194489          B          B
# 9991     6           17.0           1977    0.243205          B          B
# 9992     4            9.0           1972    0.127812          B          B
# 9993     4           22.0           2016    0.007122          B          B
# 9994    12           14.0           1992    0.161532          B          B
# 9995     3           12.0           1981    0.300323          B          B
# 9996    13            0.0           1977    0.072158          B          B
# 9997     3            5.0           1958    0.460556          B          B
# 9998     3            9.0           1969    0.194489          B          B
# 9999     9            9.0           1975    0.127376          B          B
#
#       Социал_1  Социал_2  Социал_3  Здравоохранение_1  Здравоохранение_2  \
# 9990        47      8004         3              125.0                  3
# 9991         5      1564         0              540.0                  0
# 9992        28      7287         5              320.0                  1
# 9993         1       264         0                NaN                  0
# 9994        25      5648         1               30.0                  2
# 9995        52     10311         6                NaN                  1
# 9996         2       629         1                NaN                  0
# 9997        20      4386        14                NaN                  1
# 9998        47      8004         3              125.0                  3
# 9999        43      8429         3                NaN                  3
#
#       Магазины_1 Магазины_2
# 9990           5          B
# 9991           0          B
# 9992           3          B
# 9993           1          B
# 9994           4          B
# 9995           9          B
# 9996           0          A
# 9997           5          B
# 9998           5          B
# 9999           9          B

# %%
#4, 12, 15 дзззззззззззззззззззззззззззззззззззззззззззз

# %% [markdown]
# ## 12. Выделите пять последних колонок в отдельную таблицу. Удалите в ней строки, в которых цена ниже среднего. Присоедините эту таблицу к изначальной (выберите самый подходящий тип соединения).

# %% [markdown]
# ## 13. Выведите таблицу из первоначального набора данных, содержащую площадь квартиры и цену только для трёхкомнатных квартир.

# %% [markdown]
# ## 14. Сохраните получившуюся таблицу в файлы формата csv и xlsx. Прочитайте их и убедитесь, что данные отображаются корректно.

# %% [markdown]
# ## 15. Создайте в Excel или другом табличном редакторе таблицу, содержащую несколько численных и текстовых полей. Прочитайте ее в программу при помощи pandas.

# %% [markdown]
# ## 16. Используя изначальную версию датасета считайте в ноутбук первые 400 строк.

# %%
df = pd.read_csv("data.csv")
df
df1 = df[:400]
df1
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0    11809          27    3.0  115.027311         NaN           10.0      4
# 1     3013          22    1.0   39.832524   23.169223            8.0      7
# 2     8215           1    3.0   78.342215   47.671972           10.0      2
# 3     2352           1    1.0   40.409907         NaN            1.0     10
# 4    13866          94    2.0   64.285067   38.562517            9.0     16
# ..     ...         ...    ...         ...         ...            ...    ...
# 395   3207          52    3.0   80.288769   81.668797            0.0     10
# 396   6501          23    3.0   70.462149         NaN            0.0      4
# 397  11352          44    2.0   44.403647   29.919342            5.0      3
# 398   3809           6    1.0   53.392700   54.670782            1.0      7
# 399   6005          57    3.0   92.204588   51.933214           11.0     22
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0          10.0       2014   0.075424         B         B        11      3097
# 1           8.0       1966   0.118537         B         B        30      6207
# 2          17.0       1988   0.025609         B         B        33      5261
# 3          22.0       1977   0.007122         B         B         1       264
# 4          16.0       1972   0.282798         B         B        33      8667
# ..          ...        ...        ...       ...       ...       ...       ...
# 395        17.0       1977   0.371149         B         B        34      7065
# 396         4.0       1977   0.034656         B         B         0       168
# 397         9.0       1971   0.122190         B         B        25      4724
# 398         1.0       1977   0.243205         B         B         5      1564
# 399        23.0       2007   0.133215         B         B        49     11395
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0           0           NaN            0        0       B  305018.871089
# 1           1        1183.0            1        0       B  177734.553407
# 2           0         240.0            3        1       B  282078.720850
# 3           0           NaN            0        1       B  168106.007630
# 4           2           NaN            0        6       B  343995.102962
# ..        ...           ...          ...      ...     ...            ...
# 395         1         750.0            2        5       B  181796.476207
# 396         0           NaN            0        0       B  130704.438895
# 397         2        1308.0            1        3       B  221886.465942
# 398         0         540.0            0        0       B  129606.282905
# 399         3        1406.0            3        4       A  451014.578477
#
# [400 rows x 20 columns]

# %%
df400 = pd.read_csv('data.csv', nrows = 400)
df400
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0    11809          27    3.0  115.027311         NaN           10.0      4
# 1     3013          22    1.0   39.832524   23.169223            8.0      7
# 2     8215           1    3.0   78.342215   47.671972           10.0      2
# 3     2352           1    1.0   40.409907         NaN            1.0     10
# 4    13866          94    2.0   64.285067   38.562517            9.0     16
# ..     ...         ...    ...         ...         ...            ...    ...
# 395   3207          52    3.0   80.288769   81.668797            0.0     10
# 396   6501          23    3.0   70.462149         NaN            0.0      4
# 397  11352          44    2.0   44.403647   29.919342            5.0      3
# 398   3809           6    1.0   53.392700   54.670782            1.0      7
# 399   6005          57    3.0   92.204588   51.933214           11.0     22
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0          10.0       2014   0.075424         B         B        11      3097
# 1           8.0       1966   0.118537         B         B        30      6207
# 2          17.0       1988   0.025609         B         B        33      5261
# 3          22.0       1977   0.007122         B         B         1       264
# 4          16.0       1972   0.282798         B         B        33      8667
# ..          ...        ...        ...       ...       ...       ...       ...
# 395        17.0       1977   0.371149         B         B        34      7065
# 396         4.0       1977   0.034656         B         B         0       168
# 397         9.0       1971   0.122190         B         B        25      4724
# 398         1.0       1977   0.243205         B         B         5      1564
# 399        23.0       2007   0.133215         B         B        49     11395
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0           0           NaN            0        0       B  305018.871089
# 1           1        1183.0            1        0       B  177734.553407
# 2           0         240.0            3        1       B  282078.720850
# 3           0           NaN            0        1       B  168106.007630
# 4           2           NaN            0        6       B  343995.102962
# ..        ...           ...          ...      ...     ...            ...
# 395         1         750.0            2        5       B  181796.476207
# 396         0           NaN            0        0       B  130704.438895
# 397         2        1308.0            1        3       B  221886.465942
# 398         0         540.0            0        0       B  129606.282905
# 399         3        1406.0            3        4       A  451014.578477
#
# [400 rows x 20 columns]

# %% [markdown]
# ## 17. Постройте круговую диаграмму для признака Rooms, иллюстрирующую количество квартир в процентах в зависимости от количества комнат. Сделайте сектор с наибольшим числом квартир выдвинутым.

# %%
df400['Rooms'].value_counts()
# Out:
# 1.0    160
# 2.0    134
# 3.0     96
# 4.0     10
# Name: Rooms, dtype: int64

# %%
df400['Rooms'][df['Rooms'] == 1].count()
# Out:
# 160

# %%
labels = ['Количество комнат 1', 'Количество комнат 2', 'Количество комнат 3', 'Количество комнат 4' ]

# %%
values = [df400['Rooms'][df['Rooms'] == 1].count(), df400['Rooms'][df['Rooms'] == 2].count(), df400['Rooms'][df['Rooms'] == 3].count(), df400['Rooms'][df['Rooms'] == 4].count()]
values
# Out:
# [160, 134, 96, 10]

# %%
plt.pie(values, labels = labels, autopct = '%1.1f%%', explode = [0.05,0,0,0], radius = 1.5, startangle = 90)
plt.show()

# %%
labels = ['Количество квартир 1-5', 'Количество квартир 6-10', 
          'Количество квартир 11-15', 'Количество квартир 15>' ]

# %%
values = [df400.Floo[(df['Floor'] >== 1) & (df400['Floor'] <= 5)].count(), 
          df400.Floo[(df['Floor'] >== 1] & (df400['Floor'] <= 5)].count()

values
# Out:
#   Input In [30]
#     values = [df400.Floo[(df['Floor'] >== 1) & (df400['Floor'] <= 5)].count(),
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 18. Постройте гистограмму по целевой переменной Price. Оцените визуально, по какой цене продаётся наибольшее количество квартир.

# %% [markdown]
# ## 19. Постройте диаграммы рассеяния для признаков Rooms, Square, HouseFloor, HouseYear в зависимости от целевой переменной Price в одной области figure. Оцените визуально, есть ли среди них такие, на которых разброс точек близок к линейной функции.

# %%
f = plt.figure(figsize = (16,10))
ax = f.subplots(2,2)
ax[0,0].scatter(df400['Rooms'], df400['Price'])
ax[0,1].scatter(df400['Square'], df400['Price'])

plt.suptitle('диаграммы рассеяния для признаков Rooms, Square, HouseFloor, HouseYear в зависимости от целевой переменной Price в одной области figure.', fontsize = 20)
plt.show()

# %% [markdown]
# ## 20. Постройте ядерную оценку плотности целевой переменной Price. Оцените визуально, напоминает ли полученный график нормальное распределение. Постройте двумерную ядерную оценку плотности для целевой переменной Price и признака HouseFloor, затем оцените визуально на каких этажах и по какой цене продаётся основная масса квартир.

# %% [markdown]
# ## 21. Постройте ящиковую диаграмму признака Square. Оцените визуально имеются ли выбросы, и, если да, то начиная с какого размера площади значение признака можно считать выбросом.

# %%
f = plt.figure(figsize=(10,10))
sns.boxplot(y='Square', data = df400, color='green', orient='h')
plt.title('Ящиковая диаграмма признака Square', fontsize=20, pad = 20)
plt.show()
# Out:
# C:\Users\mehro\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %% [markdown]
# ## 22. При помощи сетки графиков PairGrid визуализируйте попарные отношения признаков Rooms, Square, HouseFloor, HouseYear, Price следующим образом: на диагонали - гистограммы, под диагональю - ядерные оценки плотности, над диагональю - диаграммы рассеяния. По результатам визуализации сделайте выводы.

# %%
col = [ "Rooms", "Square", "HouseFloor", "HouseYear", "Price"]
g = sns.PairGrid(data=df400, x_vars=col, y_vars=col)
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_upper(sns.scatterplot)
g.fig.suptitle('Попарные отношения признаков Rooms, Square, HouseFloor, HouseYear, Price', y = 1.05, fontsize = 15)
plt.show()

# %% [markdown]
# ## 23. Постройте тепловую карту матрицы корреляции (df.corr()) признаков Rooms, Square, HouseFloor, HouseYear, Price. По ней определите, какие признаки являются зависимыми (у таких признаков коэффициент корреляции близок к единице).

# %%
corr = df400[["Rooms", "Square", "HouseFloor", "HouseYear", "Price"]].corr()
corr
# Out:
#                Rooms    Square  HouseFloor  HouseYear     Price
# Rooms       1.000000  0.792283    0.022855  -0.007591  0.576896
# Square      0.792283  1.000000    0.127977   0.198896  0.576114
# HouseFloor  0.022855  0.127977    1.000000   0.395669  0.110327
# HouseYear  -0.007591  0.198896    0.395669   1.000000  0.044058
# Price       0.576896  0.576114    0.110327   0.044058  1.000000

# %%
f = plt.figure(figsize = (10,8))
sns.heatmap(corr, annot=True, fmt = '.1f', cmap = 'hot')
plt.title('Тепловая карта матрицы корреляции');
